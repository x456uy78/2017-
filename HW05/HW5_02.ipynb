# %%
# %matplotlib inline
import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
df = web.DataReader('2330.TW', 'yahoo', datetime(2016, 1, 1))

print(df.head())
print(df.tail())
# Out:
#              Open   High    Low  Close   Adj Close      Volume
# Date
# 2016-01-04  143.0  143.5  139.0  139.5  129.905670  39169000.0
# 2016-01-05  139.0  140.0  137.0  138.0  128.508820  46381000.0
# 2016-01-06  138.0  138.0  135.0  135.5  126.180771  53617000.0
# 2016-01-07  134.5  135.0  130.5  133.0  123.852715  62539000.0
# 2016-01-08  132.0  135.0  132.0  134.0  124.783943  50123000.0
#              Open   High    Low  Close  Adj Close       Volume
# Date
# 2017-11-30  226.5  230.5  226.0  226.0      226.0  109231770.0
# 2017-12-01  228.5  233.5  227.5  231.0      231.0   37446265.0
# 2017-12-04  232.5  234.5  231.0  234.0      234.0   21635032.0
# 2017-12-05  231.0  231.0  228.5  229.5      229.5   29664765.0
# 2017-12-06  228.0  229.5  226.5  227.0      227.0   32371690.0

# %%
df[['Close','Volume']].plot(subplots = True, figsize = (10, 8))
plt.legend(loc='best')

# %%
import kchart

# %%
kchart.draw(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-22a1952cd8fb> in <module>()
# ----> 1 kchart.draw(df)
#
# AttributeError: module 'kchart' has no attribute 'draw'
