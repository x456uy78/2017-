# %%
import ffn
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
import pickle
import requests
import talib
from io import StringIO
from talib import MA_Type

# %%
# 讀出預先下載好的股價資料
with open('stockdata', 'rb') as f:
    data = pickle.load(file=f)

# %% [markdown]
# # Q1. 畫出 Diamond Shape

# %%
def diamond(n):
    for i in range(1,n):
        print(" "*(n-i)+"*"*(2*i-1))
        
    for j in range(n,0,-1):
        print(" "*(n-j)+"*"*(2*j-1))

# %%
diamond(3)
# Out:
#   *
#  ***
# *****
#  ***
#   *

# %% [markdown]
# # Q2. 刪除重複性資料
#
# 從 symbols01.txt 跟 symbols02.txt 讀入兩組股票代號，合併兩組代號，輸出一份無重複的股票代號到 symbols03.txt。

# %%
with open('symbols01.txt','r') as file:
    text_1 = file.read()
    text_1=text_1.split("\n")
    set01=set(text_1)

# %%
with open('symbols02.txt','r') as file:
    text_2 = file.read()
    text_2=text_2.split("\n")
    set02=set(text_2)

# %%
set03=(set01|set02)
symbols03=list(set03)

# %%
with open('symbols03.txt', 'w') as f:
    for symbol in symbols03:
        f.write(symbol.strip().upper() + "\n")

# %% [markdown]
# # Q3. 下載台灣上市公司基本資料

# %% [markdown]
# 寫一個程式從 [http://dts.twse.com.tw/opendata/t187ap03_L.csv](http://dts.twse.com.tw/opendata/t187ap03_L.csv) 下載台灣上市公司基本資料，並輸出成 pandas dataframe。

# %%
r=requests.get("http://dts.twse.com.tw/opendata/t187ap03_L.csv")

# %%
r.encoding="big5"
data_1= StringIO(r.text)
pd.read_csv(data_1, skiprows=1)
# Out:
#                       公司代號      公司名稱                                   產業別  \
# 1101            台灣水泥股份有限公司      水泥工業                         台北市中山北路2段113號
# 1102            亞洲水泥股份有限公司      水泥工業                台北市大安區敦化南路2段207號30、31樓
# 1103            嘉新水泥股份有限公司      水泥工業                          台北市中山北路2段96號
# 1104            環球水泥股份有限公司      水泥工業                      台北市南京東路二段125號10樓
# 1108            幸福水泥股份有限公司      水泥工業                         台北市松江路237號15樓
# 1109            信大水泥股份有限公司      水泥工業                           台北市寶慶路37號7樓
# 1110            東南水泥股份有限公司      水泥工業                     高雄市前金區五福三路21號4樓之1
# 1201          味全食品工業股份有限公司      食品工業                            台北市松江路125號
# 1203              味王股份有限公司      食品工業                        台北市中山北路二段79號5樓
# 1210          大成長城企業股份有限公司      食品工業                          台南市永康區蔦松二街三號
# 1213           大西洋飲料股份有限公司      食品工業                     新北市三重區重陽路三段99號10樓
# 1215          台灣卜蜂企業股份有限公司      食品工業                         台北市松江路八十七號十七樓
# 1216            統一企業股份有限公司      食品工業                    71001台南市永康區中正路301號
# 1217             愛之味股份有限公司      食品工業                         嘉義縣民雄鄉工業二路11號
# 1218            泰山企業股份有限公司      食品工業                           彰化縣田中鎮興工路6號
# 1219            福壽實業股份有限公司      食品工業                          台中市沙鹿區沙田路45號
# 1220            台榮產業股份有限公司      食品工業                    台北市中山區南京東路二段206號6樓
# 1225            福懋油脂股份有限公司      食品工業                       台中市大肚區沙田路一段453號
# 1227            佳格食品股份有限公司      食品工業                        台北市仁愛路三段136號5樓
# 1201           http://www.weichuan.com.tw NaN
# 1203                http://www.vewong.com NaN
# 1210                http://www.dachan.com NaN
# 1213         http://www.applesidra.com.tw NaN
# 1215              http://www.cptwn.com.tw NaN
# 1216      http://www.uni-president.com.tw NaN
# 1217                       www.agv.com.tw NaN
# 1218                    www.taisun.com.tw NaN
# 1219                    www.fwusow.com.tw NaN
# 1220           http://www.tairoun.com.tw/ NaN
# 1225                     WWW.FOPCO.COM.TW NaN
# 1227          http://www.sfworldwide.com/ NaN
# 1229               http://www.lhic.com.tw NaN
# 1231                   www.lianhwa.com.tw NaN
# 1232               http://www.ttet.com.tw NaN
# 1233            http://www.tenren.com.tw/ NaN
# 1234                   www.heysong.com.tw NaN
# 1235              www.shintai-feed.com.tw NaN
# 1236                     www.hunya.com.tw NaN
# 1256          http://www.myfreshjuice.com NaN
# 1262              www.greenseal-group.com NaN
# 1301                http://www.fpc.com.tw NaN
# 1303                http://www.npc.com.tw NaN
# ...                                   ...  ..
# 9912              http://www.agneovo.com/ NaN
# 9914                    www.merida.com.tw NaN
# 9917                     WWW.SECOM.COM.TW NaN
# 9918        http://www.shinshingas.com.tw NaN
# 9919       http://www.knh.com.tw/main.php NaN
# 9921        http://www.giant-bicycles.com NaN
# 9924                   www.fuhsing.com.tw NaN
# 9925                       www.sks.com.tw NaN
# 9926        http://www.shinhaigas.com.tw/ NaN
# 9927                     www.tmicl.com.tw NaN
# 9928                       www.ctv.com.tw NaN
# 9929      http://www.choicecompany.com.tw NaN
# 9930                       www.chc.com.tw NaN
# 9931                     www.hkgas.com.tw NaN
# 9933                      www.ctci.com.tw NaN
# 9934                   www.globeunion.com NaN
# 9935             http://www.chingfeng.com NaN
# 9937             http://www.npcgas.com.tw NaN
# 9938                 http://www.paiho.com NaN
# 9939           http://www.honchuan.com.tw NaN
# 9940                     WWW.SINYI.COM.TW NaN
# 9941                http://www.tac.com.tw NaN
# 9942                       www.nak.com.tw NaN
# 9943                   www.holiday.com.tw NaN
# 9944                    www.shinih.com.tw NaN
# 9945                www.rt-develop.com.tw NaN
# 9946              www.sanfarproperty.com/ NaN
# 9955                      www.sdti.com.tw NaN
# 9958                   www.century.com.tw NaN
# 合計:共922筆                              NaN NaN
#
# [923 rows x 26 columns]

# %% [markdown]
# # Q4. 畫出技術曲線
#
# 請畫出除了上課提過的線型之外的任何技術曲線，並寫註解說明。

# %%
df1 = data['GOOG']

# %%
df1.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-12-31  769.500000  769.500000  758.340027  758.880005  758.880005
# 2016-01-04  743.000000  744.059998  731.257996  741.840027  741.840027
# 2016-01-05  746.450012  752.000000  738.640015  742.580017  742.580017
# 2016-01-06  730.000000  747.179993  728.919983  743.619995  743.619995
# 2016-01-07  730.309998  738.500000  719.059998  726.390015  726.390015
#
#              Volume
# Date
# 2015-12-31  1500900
# 2016-01-04  3272800
# 2016-01-05  1950700
# 2016-01-06  1947000
# 2016-01-07  2963700

# %%
close=pd.DataFrame(df1["Close"])
short_win = 12    # 短期EMA平滑天数
long_win  = 26    # 長期EMA平滑天数
macd_win  = 20    # DEA線平滑天数
macd_tmp  =  talib . MACD ( df1.Close.values , fastperiod = short_win ,slowperiod = long_win ,signalperiod = macd_win )
df1['DIF'] =macd_tmp [ 0 ]
df1['DEA'] =macd_tmp [ 1 ]
df1['MACD']=macd_tmp [ 2 ]

# %%
type(DIF)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure()#畫出macd,dea,dif 並把三張圖合併再一起 綠色是macd 橘色dif 藍色是dea
ax = df1['MACD'].plot(kind="bar",color='g');plt.xticks(rotation=0)
ax2 = ax.twinx()
ax2.plot(ax.get_xticks(),df1[['DIF', 'DEA']])
# Out:
# [<matplotlib.lines.Line2D at 0x27aad9158d0>,
#  <matplotlib.lines.Line2D at 0x27aad90fe48>]

# %% [markdown]
# # Q5. 策略回測

# %%
# 計算 MaxDD
def DrawDownAnalysis(cumRet):
    dd_series = ffn.core.to_drawdown_series(cumRet)
    dd_details = ffn.core.drawdown_details(dd_series)
    return dd_details['drawdown'].min(), dd_details['days'].max()

# %%
# 利用策略產生的持有部位資訊，計算底下四個指標來判斷投資績效
# sharpe ratio: 判斷報酬的好壞跟穩定度，數值越大越好
# maxdd: maximum drawdown, 最糟糕的狀況會賠幾 %
# maxddd: maximum drawdown duration, 低於上一次最高報酬的天數
# cumRet[-1]: 最後賺的 % 數

def indicators(df):
    dailyRet = df['Close'].pct_change()
    excessRet = (dailyRet - 0.04/252)[df['positions'] == 1]
    SharpeRatio = np.sqrt(252.0)*np.mean(excessRet)/np.std(excessRet)
    
    cumRet = np.cumprod(1+excessRet)
    
    maxdd, maxddd = DrawDownAnalysis(cumRet)
    
    return SharpeRatio, maxdd, maxddd, cumRet[-1]

# %%
# 這是我們的策略的部分
# 主要只是要算出進出的訊號 signals 跟何時持有部位 positions
# 底下是一個突破系統的範例

def Breakout_strategy(df):
    # Donchian Channel
    df['20d_high'] = np.round(pd.Series.rolling(df['Close'], window=20).max(), 2)
    df['10d_low'] = np.round(pd.Series.rolling(df['Close'], window=10).min(), 2)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] > df['20d_high'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] < df['10d_low'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def RSI_7030_strategy(df):
    df['RSI'] = talib.RSI(df['Close'].values)
    
    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['RSI'][t-1] < 30:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['RSI'][t-1] > 70:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def BBands_strategy(df):
    df['UBB'], df['MBB'], df['LBB'] = talib.BBANDS(df['Close'].values, matype=MA_Type.T3)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] < df['LBB'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] > df['UBB'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def apply_strategy(strategy, df):
    return strategy(df)

# %%
#DIF、DEA均為正，DIF向上突破DEA，買入信号
#DIF、DEA均為負，DIF向下跌破DEA，賣出信号
def M064810004_strategy(df):
    close=pd.DataFrame(df["Close"])
    short_win = 12    # 短期EMA平滑天数
    long_win  = 26    # 長期EMA平滑天数
    macd_win  = 20    # DEA線平滑天数
    macd_tmp  =  talib.MACD( df['Close'].values,fastperiod = short_win ,slowperiod = long_win ,signalperiod = macd_win )
    df['DIF'] =macd_tmp [ 0 ]
    df['DEA'] =macd_tmp [ 1 ]
    df['MACD']=macd_tmp [ 2 ]
    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['DIF'][t] > 0 and df['DEA'][t] >0 and df['DIF'][t] > df['DEA'][t] and df['DIF'][t-1]<df['DEA'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['DIF'][t] < 0 and df['DEA'][t] < 0 and df['DIF'][t] < df['DEA'][t] and df['DIF'][t-1]>df['DEA'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False
    
 

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
# 計算各支股票的回測結果
results = []

#strategies = [Breakout_strategy, RSI_7030_strategy, BBands_strategy, 學號_strategy]
strategies = [Breakout_strategy, RSI_7030_strategy, BBands_strategy,M064810004_strategy]

for symbol in data:
    for strategy in strategies:
        try:
            apply_strategy(strategy, data[symbol])
            if np.all(data[symbol]['signals']==0):
                print("Symbol:", symbol, "使用", strategy.__name__, "策略沒有出現買賣訊號。")
                continue
            SharpeRatio, maxdd, maxddd, finalRet = indicators(data[symbol])
            days = (data[symbol].index[-1] - data[symbol].index[0]).days
            results.append((SharpeRatio, maxdd, maxddd, finalRet, days,
                            data[symbol][data[symbol]['signals'] > 0]['signals'].sum(), symbol, strategy.__name__))
        except Exception as e:
            print("Error occurs at symbol:", symbol, "Strategy:", strategy.__name__, "==>", e.args)
# Out:
# Symbol: NLNK 使用 M064810004_strategy 策略沒有出現買賣訊號。
# Symbol: VRA 使用 M064810004_strategy 策略沒有出現買賣訊號。

# %%
results_df = pd.DataFrame(results, columns=['sharpe','MaxDrawDown','MaxDrawDownDuration','returns', 
                                            'days', 'entries','symbol','strategy'])

# %%
results_df.head()
# Out:
#      sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries symbol  \
# 0  0.131503    -0.208296                  281  0.995734   705       11   TICC
# 1  0.395515    -0.244817                  482  1.077756   705        2   TICC
# 2  0.102787    -0.231763                  426  0.984521   705       20   TICC
# 3  0.546979    -0.315706                  281  1.122720   705        2   TICC
# 4  1.365570    -0.361485                  299  1.631388   705       12   TWIN
#
#               strategy
# 0    Breakout_strategy
# 1    RSI_7030_strategy
# 2      BBands_strategy
# 3  M064810004_strategy
# 4    Breakout_strategy

# %%
results_df.sort_values('MaxDrawDown',ascending=False).head()
# Out:
#        sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 72   6.306176    -0.003654                  122  1.028222   473        3
# 17  10.243474    -0.006251                    3  1.132402   705        1
# 73   2.038551    -0.013673                  119  1.060527   473       16
# 65   1.085572    -0.023454                  135  1.049505   384       12
# 36   3.040178    -0.023844                   58  1.073352   203        3
#
#    symbol           strategy
# 72    LCA  RSI_7030_strategy
# 17   GOOG  RSI_7030_strategy
# 73    LCA    BBands_strategy
# 65   SCAC    BBands_strategy
# 36   CSML  Breakout_strategy

# %%
results_df.sort_values('returns',ascending=False).head()
# Out:
#       sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 27  2.345149    -0.157591                   88  3.078200   705        1
# 9   2.013777    -0.219296                  167  2.477803   705        4
# 14  2.062962    -0.286661                  113  2.422460   705       22
# 77  2.136744    -0.454342                  191  2.400221   705       21
# 78  1.403947    -0.493953                   61  2.368355   705        1
#
#    symbol             strategy
# 27   RICK  M064810004_strategy
# 9    AMOT    RSI_7030_strategy
# 14   CDZI      BBands_strategy
# 77   BBGI      BBands_strategy
# 78   BBGI  M064810004_strategy
